# %%
from fastai.data.all import *
from fastai.vision.all import *
from fastai.data.transforms import get_image_files
import PIL
import torch
import numpy as np
import os

# %%
DATA_PATH = 'clean'
DATA_PATH_X = 'clean/x-data'
DATA_PATH_Y = 'clean/y-data'
CODES_PATH = "clean/codes.txt"
BATCH_SIZE = 4
IMG_SIZE = (128)

# %%
x_files = get_image_files(DATA_PATH_X)
y_files = get_image_files(DATA_PATH_Y)

# %%
def open_image(fname, size=IMG_SIZE):
    img = PIL.Image.open(fname).convert('RGB')
    img = img.resize((size, size))
    gray_img = PIL.ImageOps.grayscale(img)
    return torch.Tensor(np.array(gray_img))

# %%
def label_func(fname):
    path_y = "clean/y-data/"
    base_name_y = os.path.basename(fname)
    fname_y = os.path.join(path_y, base_name_y)
    return open_image(fname_y, size=(86))

# %%
dblock = DataBlock(
    blocks=(ImageBlock, ImageBlock),
    get_items=get_image_files,
    get_x = open_image,
    get_y = label_func,
    )

# %%
dls = dblock.dataloaders(
                    DATA_PATH_X, valid_pct=0.2, seed=11, bs=BATCH_SIZE, 
                    batch_tfms=[ 
                    Normalize.from_stats(*imagenet_stats)]
                    )
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dls.show_batch(figsize=(6,6))

# %%
import matplotlib.pyplot as plt

tester = dls[0].one_batch()

plt.imshow(  tester[0][0].permute(1, 2, 0)  )

# %%
print(tester[0].shape)
plt.imshow(  tester[0][0].permute(1, 2, 0)  )
# Out:
# torch.Size([4, 1, 128, 128])

# %%
print(tester.shape)
plt.imshow(  tester[1][0].permute(1, 2, 0)  )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9732\115911355.py in <module>
# ----> 1 print(tester.shape)
#       2 plt.imshow(  tester[1][0].permute(1, 2, 0)  )
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
plt.imshow(  tester[1][0].permute(1, 2, 0)  )

# %% [markdown]
# ## Model

# %%
opt = ranger
metric = DiceMulti

# %%
def conv(ni, nf, ks=3, act=True):
    res = torch.nn.Conv2d(ni, nf, stride=2, kernel_size=ks, padding=ks//2)
    if act: res = torch.nn.Sequential(
        res, 
        torch.nn.ReLU(), 
        torch.nn.MaxPool2d(kernel_size=2, stride=2))
    return res

# %%
def deconv(ni, nf, ks=3, act=True):
    res = torch.nn.ConvTranspose2d(ni, nf, stride=2, kernel_size=ks, padding=ks//2)
    if act: res = torch.nn.Sequential(
        res, 
        torch.nn.ReLU(), 
        torch.nn.Upsample(scale_factor=2, mode='bilinear'))
    return res

# %%
cnn = torch.nn.Sequential(
    conv(1 ,8, ks=5),        #14x14
    conv(8 ,16),             #7x7
    conv(16,32),             #4x4        
    torch.nn.Flatten(),
    deconv(32,16),
    deconv(16,8),
    deconv(8,1)
)

# %%
cnn = torch.nn.Sequential(
    conv(1 ,8),        #14x14
    conv(8 ,16),             #7x7
    deconv(16,8),
    deconv(8,1)
)

# %%
cnn = torch.nn.Sequential(
    conv(1 ,8, ks=5),        #14x14
    conv(8 ,16),             #7x7
    conv(16,32),             #4x4        
    deconv(32,16),
    deconv(16,8),
    deconv(8,1)
)

# %%
input_test = torch.rand(20, 1, 128, 128)
print(input_test.shape)
cnn(input_test).shape
# Out:
# torch.Size([20, 1, 128, 128])
# torch.Size([20, 1, 86, 86])

# %%
input = torch.randn(1, 16, 12, 12)
downsample = nn.Conv2d(16, 16, 3, stride=2, padding=1)
upsample = nn.ConvTranspose2d(16, 16, 3, stride=2, padding=1)

# %%
h = downsample(input)
h.size()
# Out:
# torch.Size([1, 16, 6, 6])

# %%
output = upsample(h, output_size=input.size())
output.size()
# Out:
# torch.Size([1, 16, 12, 12])

# %%
sizer = (output.size()[0], output.size()[1], output.size()[2]*2, output.size()[3]*2)
sizer
# Out:
# (1, 16, 48, 48)

# %%
output = upsample(output, output_size=sizer)
output.size()
# Out:
# torch.Size([1, 16, 48, 48])

# %%
learn = Learner(dls, cnn, loss_func=F.cross_entropy, metrics=metric)

# %%
learn.summary()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Sequential (Input shape: 4 x 1 x 128 x 128)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      4 x 8 x 65 x 65
# Conv2d                                    136        True
# ReLU
# ____________________________________________________________________________
#                      4 x 8 x 32 x 32
# MaxPool2d
# ____________________________________________________________________________
#                      4 x 16 x 17 x 17
# Conv2d                                    2064       True
# ReLU
# ____________________________________________________________________________
#                      4 x 16 x 8 x 8
# MaxPool2d
# ____________________________________________________________________________
#                      4 x 8 x 14 x 14
# ConvTranspose2d                           2056       True
# ReLU
# ____________________________________________________________________________
#                      4 x 8 x 28 x 28
# Upsample
# ____________________________________________________________________________
#                      4 x 1 x 54 x 54
# ConvTranspose2d                           129        True
# ReLU
# ____________________________________________________________________________
#                      4 x 1 x 108 x 108
# Upsample
# ____________________________________________________________________________
#
# Total params: 4,385
# Total trainable params: 4,385
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001A01CBC2048>
# Loss function: <function cross_entropy at 0x000001A0165F50D8>
#
# Callbacks:
#   - TrainEvalCallback
#   - CastToTensor
#   - Recorder
#   - ProgressCallback

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
#
#
#     <div>
#       <progress value='0' class='' max='171' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/171 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24272\2434377672.py in <module>
# ----> 1 learn.lr_find()
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\callback\schedule.py in lr_find(self, start_lr, end_lr, num_it, stop_div, show_plot, suggest_funcs)
#     294     n_epoch = num_it//len(self.dls.train) + 1
#     295     cb=LRFinder(start_lr=start_lr, end_lr=end_lr, num_it=num_it, stop_div=stop_div)
# --> 296     with self.no_logging(): self.fit(n_epoch, cbs=cb)
#     297     if suggest_funcs is not None:
#     298         lrs, losses = tensor(self.recorder.lrs[num_it//10:-5]), tensor(self.recorder.losses[num_it//10:-5])
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt, start_epoch)
#     240             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     241             self.n_epoch = n_epoch
# --> 242             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     243
#     244     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     177
#     178     def _with_events(self, f, event_type, ex, final=noop):
# --> 179         try: self(f'before_{event_type}');  f()
#     180         except ex: self(f'after_cancel_{event_type}')
#     181         self(f'after_{event_type}');  final()
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _do_fit(self)
#     229         for epoch in range(self.n_epoch):
#     230             self.epoch=epoch
# --> 231             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     232
#     233     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False, start_epoch=0):
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     177
#     178     def _with_events(self, f, event_type, ex, final=noop):
# --> 179         try: self(f'before_{event_type}');  f()
#     180         except ex: self(f'after_cancel_{event_type}')
#     181         self(f'after_{event_type}');  final()
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _do_epoch(self)
#     223
#     224     def _do_epoch(self):
# --> 225         self._do_epoch_train()
#     226         self._do_epoch_validate()
#     227
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _do_epoch_train(self)
#     215     def _do_epoch_train(self):
#     216         self.dl = self.dls.train
# --> 217         self._with_events(self.all_batches, 'train', CancelTrainException)
#     218
#     219     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     177
#     178     def _with_events(self, f, event_type, ex, final=noop):
# --> 179         try: self(f'before_{event_type}');  f()
#     180         except ex: self(f'after_cancel_{event_type}')
#     181         self(f'after_{event_type}');  final()
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in all_batches(self)
#     183     def all_batches(self):
#     184         self.n_iter = len(self.dl)
# --> 185         for o in enumerate(self.dl): self.one_batch(*o)
#     186
#     187     def _backward(self): self.loss_grad.backward()
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in one_batch(self, i, b)
#     211         b = self._set_device(b)
#     212         self._split(b)
# --> 213         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     214
#     215     def _do_epoch_train(self):
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     177
#     178     def _with_events(self, f, event_type, ex, final=noop):
# --> 179         try: self(f'before_{event_type}');  f()
#     180         except ex: self(f'after_cancel_{event_type}')
#     181         self(f'after_{event_type}');  final()
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _do_one_batch(self)
#     192         self('after_pred')
#     193         if len(self.yb):
# --> 194             self.loss_grad = self.loss_func(self.pred, *self.yb)
#     195             self.loss = self.loss_grad.clone()
#     196         self('after_loss')
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\torch\nn\functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    2994     if size_average is not None or reduce is not None:
#    2995         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 2996     return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#    2997
#    2998
#
# RuntimeError: only batches of spatial targets supported (3D tensors) but got targets of dimension: 4

# %%
learn.fit(2, 0.06)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='0' class='' max='171' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/171 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24272\529473557.py in <module>
# ----> 1 learn.fit(2, 0.06)
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt, start_epoch)
#     240             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     241             self.n_epoch = n_epoch
# --> 242             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     243
#     244     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     177
#     178     def _with_events(self, f, event_type, ex, final=noop):
# --> 179         try: self(f'before_{event_type}');  f()
#     180         except ex: self(f'after_cancel_{event_type}')
#     181         self(f'after_{event_type}');  final()
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _do_fit(self)
#     229         for epoch in range(self.n_epoch):
#     230             self.epoch=epoch
# --> 231             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     232
#     233     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False, start_epoch=0):
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     177
#     178     def _with_events(self, f, event_type, ex, final=noop):
# --> 179         try: self(f'before_{event_type}');  f()
#     180         except ex: self(f'after_cancel_{event_type}')
#     181         self(f'after_{event_type}');  final()
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _do_epoch(self)
#     223
#     224     def _do_epoch(self):
# --> 225         self._do_epoch_train()
#     226         self._do_epoch_validate()
#     227
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _do_epoch_train(self)
#     215     def _do_epoch_train(self):
#     216         self.dl = self.dls.train
# --> 217         self._with_events(self.all_batches, 'train', CancelTrainException)
#     218
#     219     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     177
#     178     def _with_events(self, f, event_type, ex, final=noop):
# --> 179         try: self(f'before_{event_type}');  f()
#     180         except ex: self(f'after_cancel_{event_type}')
#     181         self(f'after_{event_type}');  final()
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in all_batches(self)
#     183     def all_batches(self):
#     184         self.n_iter = len(self.dl)
# --> 185         for o in enumerate(self.dl): self.one_batch(*o)
#     186
#     187     def _backward(self): self.loss_grad.backward()
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in one_batch(self, i, b)
#     211         b = self._set_device(b)
#     212         self._split(b)
# --> 213         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     214
#     215     def _do_epoch_train(self):
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     177
#     178     def _with_events(self, f, event_type, ex, final=noop):
# --> 179         try: self(f'before_{event_type}');  f()
#     180         except ex: self(f'after_cancel_{event_type}')
#     181         self(f'after_{event_type}');  final()
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\fastai\learner.py in _do_one_batch(self)
#     192         self('after_pred')
#     193         if len(self.yb):
# --> 194             self.loss_grad = self.loss_func(self.pred, *self.yb)
#     195             self.loss = self.loss_grad.clone()
#     196         self('after_loss')
#
# c:\Users\CsungaBro\.conda\envs\fastai\lib\site-packages\torch\nn\functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    2994     if size_average is not None or reduce is not None:
#    2995         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 2996     return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#    2997
#    2998
#
# RuntimeError: only batches of spatial targets supported (3D tensors) but got targets of dimension: 4

# %%
# def fit(epochs=1):
#     learn = Learner(dls, cnn(), loss_func=F.cross_entropy,
#                     metrics=metric)
#     learn.fit(epochs, 0.06)
#     return learn
